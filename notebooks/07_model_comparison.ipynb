# %% [markdown]
# # Phase 7 — Nonlinear Model Comparison
#
# Train HistGradientBoosting (no heavy tuning) and compare against logistic regression on metrics, calibration-related scores (log loss / Brier), and business value.

# %%
import sys
from pathlib import Path
import json
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.models.compare import compare_models

report = compare_models()
display(pd.DataFrame(report["metrics_table"]))
print(json.dumps(report["tradeoffs"], indent=2))

# %% [markdown]
# ## How to choose
#
# | Criterion | Prefer LR when… | Prefer HGB when… |
# |---|---|---|
# | Performance | Gaps are small | Clear lift on PR-AUC / log loss / business value |
# | Interpretability | Stakeholders need coefficients | Black-box OK with later explainability |
# | Complexity / cost | Teaching, simple deploy | Slightly more capacity is worth it |
#
# We avoid extensive hyperparameter search so the comparison stays educational and reproducible.
